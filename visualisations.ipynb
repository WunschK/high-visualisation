# %%
#Imports necessary libraries
import pandas as pd
import matplotlib as plt

# %%
# creates dataframe from csv
data = pd.read_csv("data.csv")
df = pd.DataFrame(data)

# %%
df[:2]
# Out:
#    record_id  redcap_survey_identifier  \
# 0          1                       NaN
# 1          2                       NaN
#
#   short_questionnaire_transcription_project_timestamp  wer  usefulness  \
# 0                                2023-01-21 13:32:53     1           5
# 1                                2023-02-14 09:50:58     2           5
#
#    understandability  future_use  \
# 0                  5           5
# 1                  4           5
#
#                                         improvements  \
# 0  Very minor grammar issues. Word gender may be ...
# 1  The recognition of the person speaking would b...
#
#    short_questionnaire_transcription_project_complete wer-Bed
# 0                                                  2    0-10%
# 1                                                  2   11-20%

# %%
# plots a pie chart for usefulness

plot = df.plot.bar(y="usefulness", x="record_id")

# %%
# plots a pie chart for understandability

plot = df.plot.bar(y="understandability", x="record_id", color="green")

# %%
print(df["wer"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="Word Error Rate", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
print(df["usefulness"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="usefulness", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
print(df["usefulness"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="usefulness", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
distance = 0.2
separate =(distance,distance,distance,distance)
df["usefulness"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="usefulness", autopct='%1.1f%%', labels=None)
# Out:
# <Axes: title={'center': 'usefulness'}, ylabel='usefulness'>
