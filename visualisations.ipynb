# %%
#Imports necessary libraries
import pandas as pd
import matplotlib as plt

# %%
# creates dataframe from csv
data = pd.read_csv("data.csv")
df = pd.DataFrame(data)

# %%
df[:2]

# %%
# plots a pie chart for usefulness

plot = df.plot.bar(y="usefulness", x="record_id")

# %%
# plots a pie chart for understandability

plot = df.plot.bar(y="understandability", x="record_id", color="green")

# %%
print(df["wer-bed"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="Word Error Rate", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
print(df["usefulness-bed"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="Usefulness", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
print(df["future-bed"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="Future use", autopct='%1.1f%%', labels=None))
# Out:
# Axes(0.1275,0.11;0.77x0.77)

# %%
distance = 0.2
separate =(distance,distance,distance,distance)
df["understand-bed"].value_counts().plot(figsize=(8,8), kind="pie", legend=True, title="usefulness", autopct='%1.1f%%', labels=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/high/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/PycharmProjects/high/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/PycharmProjects/high/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'understand-bed'
#
# ...
